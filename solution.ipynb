# %%
# %%capture
#### Load Libraries (without cell output)

import autograd.numpy as np # import autograd wrapped numpy
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns
import sklearn
from sklearn.model_selection import train_test_split
from sklearn import neighbors, metrics
from sklearn.preprocessing import scale

import statsmodels.api as sm
from statsmodels.genmod.generalized_linear_model import GLM
from statsmodels.genmod.families import Gamma

# %%
claims = pd.read_csv("./Qualification_Package/Claims_Years_1_to_3.csv")
print(claims['claim_amount'].mean())

print(claims.shape)
# Out:
# 1187.758451280604
# (14173, 24)

# %%
claims.head(10)
# Out:
#   id_policy  year  pol_no_claims_discount  pol_duration pol_pay_freq pol_payd  \
# 0  PL042479     1                   0.000             5     Biannual       No
# 1  PL042480     1                   0.000            27       Yearly       No
# 2  PL042548     1                   0.000             2     Biannual       No
# 3  PL042474     1                   0.000            26     Biannual       No
# 4  PL042425     1                   0.070             2       Yearly       No
# 5  PL042414     1                   0.000             2      Monthly       No
# 6  PL042436     1                   0.000            16     Biannual       No
# 7  PL042456     1                   0.000             3     Biannual       No
# 8  PL042449     1                   0.319             6     Biannual       No
# 9  PL042664     1                   0.000             5      Monthly       No
#
#       pol_usage drv_sex1  drv_age1  drv_age_lic1  ...     vh_make_model  \
# 0   WorkPrivate        M        47            22  ...  zspzyfdefowgwddf
# 1       Retired        F        84            60  ...  hselphnqlvecmmyx
# 2  Professional        F        37            18  ...  demgvtbzilochupd
# 3   WorkPrivate        F        48            27  ...  aywlgifrijfokyzu
# 4   WorkPrivate        F        26             8  ...  ajtardhciglimsdi
# 5   WorkPrivate        F        33            15  ...  hselphnqlvecmmyx
# 6   WorkPrivate        M        64            46  ...  xzdsapxqliboezbc
# 7   WorkPrivate        M        68            47  ...  xpxsjmglcvcsxwdy
# 8  Professional        M        43            24  ...  xkzehzohmfrsmolg
# 9   WorkPrivate        F        36            18  ...  zspzyfdefowgwddf
#
#   vh_age   vh_fuel     vh_type vh_speed  vh_value vh_weight population  \
# 0      5    Diesel     Tourism    200.0   25000.0    1300.0        320
# 1      1    Diesel     Tourism    158.0   13390.0     885.0        530
# 2      4  Gasoline     Tourism    160.0    2088.0       0.0        960
# 3      1    Diesel     Tourism    182.0   11785.0    1080.0       1290
# 4      3    Diesel     Tourism    250.0   25250.0    1450.0         70
# 5     11    Diesel     Tourism    158.0   13390.0     885.0         10
# 6      8    Diesel     Tourism    168.0   11876.0    1225.0        240
# 7      1  Gasoline     Tourism    170.0   11129.0     927.0       1980
# 8      1    Diesel  Commercial    148.0   16702.0    1350.0       1300
# 9      4    Diesel     Tourism    200.0   25000.0    1300.0        390
#
#    town_surface_area  claim_amount
# 0               58.3        339.84
# 1              385.6       1236.00
# 2              701.5        224.33
# 3               49.8       1343.41
# 4               30.8        130.23
# 5               52.9        390.03
# 6              103.7        699.54
# 7              218.2        381.15
# 8               53.0         87.53
# 9              396.5        670.91
#
# [10 rows x 24 columns]

# %%
claims.columns
# Out:
# Index(['id_policy', 'year', 'pol_no_claims_discount', 'pol_duration',
#        'pol_pay_freq', 'pol_payd', 'pol_usage', 'drv_sex1', 'drv_age1',
#        'drv_age_lic1', 'drv_drv2', 'drv_sex2', 'drv_age2', 'drv_age_lic2',
#        'vh_make_model', 'vh_age', 'vh_fuel', 'vh_type', 'vh_speed', 'vh_value',
#        'vh_weight', 'population', 'town_surface_area', 'claim_amount'],
#       dtype='object')

# %%
claims['pol_pay_freq'] = claims['pol_pay_freq'].replace( {'Biannual': 2, 'Yearly': 1, 'Monthly': 12, 'Quarterly': 4} )
claims['pol_payd'] = claims['pol_payd'].replace( {'No': 0, 'Yes': 1} )
claims['drv_sex1'] = claims['drv_sex1'].replace( {'M': 1, 'F': 0} )
claims['vh_type'] = claims['vh_type'].replace( {'Tourism': 1, 'Commercial': 0} )

claims.head(10)
# Out:
#   id_policy  year  pol_no_claims_discount  pol_duration  pol_pay_freq  \
# 0  PL042479     1                   0.000             5             2
# 1  PL042480     1                   0.000            27             1
# 2  PL042548     1                   0.000             2             2
# 3  PL042474     1                   0.000            26             2
# 4  PL042425     1                   0.070             2             1
# 5  PL042414     1                   0.000             2            12
# 6  PL042436     1                   0.000            16             2
# 7  PL042456     1                   0.000             3             2
# 8  PL042449     1                   0.319             6             2
# 9  PL042664     1                   0.000             5            12
#
#    pol_payd     pol_usage  drv_sex1  drv_age1  drv_age_lic1  ...  \
# 0         0   WorkPrivate         1        47            22  ...
# 1         0       Retired         0        84            60  ...
# 2         0  Professional         0        37            18  ...
# 3         0   WorkPrivate         0        48            27  ...
# 4         0   WorkPrivate         0        26             8  ...
# 5         0   WorkPrivate         0        33            15  ...
# 6         0   WorkPrivate         1        64            46  ...
# 7         0   WorkPrivate         1        68            47  ...
# 8         0  Professional         1        43            24  ...
# 9         0   WorkPrivate         0        36            18  ...
#
#       vh_make_model vh_age   vh_fuel  vh_type vh_speed  vh_value vh_weight  \
# 0  zspzyfdefowgwddf      5    Diesel        1    200.0   25000.0    1300.0
# 1  hselphnqlvecmmyx      1    Diesel        1    158.0   13390.0     885.0
# 2  demgvtbzilochupd      4  Gasoline        1    160.0    2088.0       0.0
# 3  aywlgifrijfokyzu      1    Diesel        1    182.0   11785.0    1080.0
# 4  ajtardhciglimsdi      3    Diesel        1    250.0   25250.0    1450.0
# 5  hselphnqlvecmmyx     11    Diesel        1    158.0   13390.0     885.0
# 6  xzdsapxqliboezbc      8    Diesel        1    168.0   11876.0    1225.0
# 7  xpxsjmglcvcsxwdy      1  Gasoline        1    170.0   11129.0     927.0
# 8  xkzehzohmfrsmolg      1    Diesel        0    148.0   16702.0    1350.0
# 9  zspzyfdefowgwddf      4    Diesel        1    200.0   25000.0    1300.0
#
#    population  town_surface_area  claim_amount
# 0         320               58.3        339.84
# 1         530              385.6       1236.00
# 2         960              701.5        224.33
# 3        1290               49.8       1343.41
# 4          70               30.8        130.23
# 5          10               52.9        390.03
# 6         240              103.7        699.54
# 7        1980              218.2        381.15
# 8        1300               53.0         87.53
# 9         390              396.5        670.91
#
# [10 rows x 24 columns]

# %%
claims['pol_usage'].unique()
# Out:
# array(['WorkPrivate', 'Retired', 'Professional', 'AllTrips'], dtype=object)

# %%
x = claims.iloc[:,:-1]
y = claims.iloc[:,-1:]

print(x.shape, y.shape)
# Out:
# (14173, 23) (14173, 1)

# %%
x_train, x_test, y_train, y_test = train_test_split(
    x,
    y, 
    test_size = 0.25, # train is 75%, test is 25% 
    random_state = 0, 
    #stratify = y,
)

# %%
k_range = range(1, 15)
scores_r = [] 

for k in k_range:
    knn_r = neighbors.KNeighborsRegressor(n_neighbors=k)
    knn_r.fit(x_train, y_train)
    y_r_pred = knn_r.predict(x_test)
    scores_r.append(round(np.sqrt(metrics.mean_squared_error(y_test, y_r_pred)), 2))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16292\3624060619.py in ?()
#       2 scores_r = []
#       3
#       4 for k in k_range:
#       5     knn_r = neighbors.KNeighborsRegressor(n_neighbors=k)
# ----> 6     knn_r.fit(x_train, y_train)
#       7     y_r_pred = knn_r.predict(x_test)
#       8     scores_r.append(round(np.sqrt(metrics.mean_squared_error(y_test, y_r_pred)), 2))
#
# c:\Users\kyle\OneDrive\Programs\Cooperators_2024\.venv\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1470                 skip_parameter_validation=(
#    1471                     prefer_skip_nested_validation or global_skip_validation
#    1472                 )
#    1473             ):
# -> 1474                 return fit_method(estimator, *args, **kwargs)
#
# c:\Users\kyle\OneDrive\Programs\Cooperators_2024\.venv\Lib\site-packages\sklearn\neighbors\_regression.py in ?(self, X, y)
#     219         -------
#     220         self : KNeighborsRegressor
#     221             The fitted k-nearest neighbors regressor.
#     222         """
# --> 223         return self._fit(X, y)
#
# c:\Users\kyle\OneDrive\Programs\Cooperators_2024\.venv\Lib\site-packages\sklearn\neighbors\_base.py in ?(self, X, y)
#     473     def _fit(self, X, y=None):
#     474         if self._get_tags()["requires_y"]:
#     475             if not isinstance(X, (KDTree, BallTree, NeighborsBase)):
# --> 476                 X, y = self._validate_data(
#     477                     X, y, accept_sparse="csr", multi_output=True, order="C"
#     478                 )
#     479
#
# c:\Users\kyle\OneDrive\Programs\Cooperators_2024\.venv\Lib\site-packages\sklearn\base.py in ?(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     646                 if "estimator" not in check_y_params:
#     647                     check_y_params = {**default_check_params, **check_y_params}
#     648                 y = check_array(y, input_name="y", **check_y_params)
#     649             else:
# --> 650                 X, y = check_X_y(X, y, **check_params)
#     651             out = X, y
#     652
#     653         if not no_val_X and check_params.get("ensure_2d", True):
#
# c:\Users\kyle\OneDrive\Programs\Cooperators_2024\.venv\Lib\site-packages\sklearn\utils\validation.py in ?(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1259         raise ValueError(
#    1260             f"{estimator_name} requires y to be passed, but the target y is None"
#    1261         )
#    1262
# -> 1263     X = check_array(
#    1264         X,
#    1265         accept_sparse=accept_sparse,
#    1266         accept_large_sparse=accept_large_sparse,
#
# c:\Users\kyle\OneDrive\Programs\Cooperators_2024\.venv\Lib\site-packages\sklearn\utils\validation.py in ?(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     994                         )
#     995                     array = xp.astype(array, dtype, copy=False)
#     996                 else:
#     997                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
# --> 998             except ComplexWarning as complex_warning:
#     999                 raise ValueError(
#    1000                     "Complex data not supported\n{}\n".format(array)
#    1001                 ) from complex_warning
#
# c:\Users\kyle\OneDrive\Programs\Cooperators_2024\.venv\Lib\site-packages\sklearn\utils\_array_api.py in ?(array, dtype, order, copy, xp)
#     517         # Use NumPy API to support order
#     518         if copy is True:
#     519             array = numpy.array(array, order=order, dtype=dtype)
#     520         else:
# --> 521             array = numpy.asarray(array, order=order, dtype=dtype)
#     522
#     523         # At this point array is a NumPy ndarray. We convert it to an array
#     524         # container that is consistent with the input's namespace.
#
# c:\Users\kyle\OneDrive\Programs\Cooperators_2024\.venv\Lib\site-packages\pandas\core\generic.py in ?(self, dtype)
#    2148     def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
#    2149         values = self._values
# -> 2150         arr = np.asarray(values, dtype=dtype)
#    2151         if (
#    2152             astype_is_view(values.dtype, arr.dtype)
#    2153             and using_copy_on_write()
#
# ValueError: could not convert string to float: 'PL071354'
