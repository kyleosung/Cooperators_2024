# %%
from solution_library import *

# %%
claims = load_claims()

# %%
x_train, x_test, y_train, y_test = preprocess_xy(claims)
# Out:
# c:\Users\kyle\OneDrive\Programs\Cooperators_2024\solution_library.py:72: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   claims['pol_pay_freq'] = claims['pol_pay_freq'].replace( {'Biannual': 2, 'Yearly': 1, 'Monthly': 12, 'Quarterly': 4} )
# c:\Users\kyle\OneDrive\Programs\Cooperators_2024\solution_library.py:73: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   claims['pol_payd'] = claims['pol_payd'].replace( {'No': 0, 'Yes': 1} )
# ...

# %%
model = VotingRegressor([('kn', KNeighborsRegressor(n_neighbors=30)), ('sv', svm.SVR())])
model.fit(x_train, y_train)
# Out:
# VotingRegressor(estimators=[('kn', KNeighborsRegressor(n_neighbors=30)),
#                             ('sv', SVR())])

# %%
y_pred = model.predict(x_test)
print(RMSE(y_pred, y_test))
# Out:
# 1373.5700959204958

# %%
predictions = predict(load_tests(), model)

predictions
# Out:
# c:\Users\kyle\OneDrive\Programs\Cooperators_2024\solution_library.py:119: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   claims['pol_pay_freq'] = claims['pol_pay_freq'].replace( {'Biannual': 2, 'Yearly': 1, 'Monthly': 12, 'Quarterly': 4} )
# c:\Users\kyle\OneDrive\Programs\Cooperators_2024\solution_library.py:120: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   claims['pol_payd'] = claims['pol_payd'].replace( {'No': 0, 'Yes': 1} )
# ...

# %%
predictions.to_csv('predictions_v1.csv')
